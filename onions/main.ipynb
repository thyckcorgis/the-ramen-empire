# %%
import pandas as pd

# %%
df = pd.read_csv("Location_of_warehouses_Bangalore.csv")

# %%
df
# Out:
#     Sl.no                                    Wholesalers  \
# 0       1                          Aravind Onion Traders
# 1       2                                    R K Traders
# 2       3                             Rudreswara Traders
# 3       4                                     Kk Traders
# 4       5                                    RIZ Traders
# 5       6  Sri Lakshmi Venkateshwara Prasanna Onion Shop
# 6       7                                    City Market
# 7       8                                 KBB Onion Shop
# 8       9                                     Onion Shop
# 9      10                            Yeshwanthpur Market
# 10     11                               M/S. Ayush & Co.
# 11     12                           Sri Vinayaka Traders
# 12     13                              Gowri Enterprises
# 13     14                                 A.H Onion Mart
# 14     15                                    Onion Plaza
# ...
